# %%
#!pip install selenium
from datetime import datetime 
import pandas as pd
import selenium
import pickle
import re
import json
import csv

from random import randint
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
print('Selenium Version:',selenium.__version__)
import datetime
# Out:
# Selenium Version: 3.141.0

# %%
def scrubadub(variable):
    myList=(list(variable))
    clean=[]
    for i in range(0,len(myList)):
        #Regular expressions for removing web addresses
        url_reg  = r'[a-z]*[:.]+\S+'
        #and replacing with nothing
        url_text=re.sub(url_reg, '', myList[i])
        sep = " "
        junk = re.findall(r"(?i)\b[a-z]+\b", url_text)
        #join the seperated words
        junk = sep.join(junk)
        #remove _s_ spaces from text after punctuation removal
        S_space = re.sub(r' s ','',junk)
        clean.append(S_space)
    return clean

# %%
from datetime import datetime 
d = datetime.today()
today=str(d.month)+'-'+str(d.day)+'-'+str(d.year)

# %%
GlassFile='glassdoor-scrape_2-1-2019.csv'
IndeedFile='Indeed-scrape_2-1-2019.csv'
MonsFile='Monster-scrape_2-1-2019.csv'

# %%
try:
    Glassdoor=pd.read_csv('glassdoor-scrape_'+today+'.csv',sep='#')
    Indeed=pd.read_csv('Indeed-scrape_'+today+'.csv',sep='#')
    Monster=pd.read_csv('monster-scrape_'+today+'.csv',sep='#')
except:
    Glassdoor=pd.read_csv(GlassFile,sep='#')
    Indeed=pd.read_csv(IndeedFile,sep='#')
    Monster=pd.read_csv(MonsFile,sep='#')

# %%
if 'Unnamed: 0' in Glassdoor.columns:
    Glassdoor=Glassdoor.drop(['Unnamed: 0'],axis=1)
if 'Unnamed: 0' in Indeed.columns:
    Indeed=Indeed.drop(['Unnamed: 0'],axis=1)
if 'Unnamed: 0' in Monster.columns:
    Monster=Monster.drop(['Unnamed: 0'],axis=1)

# %%
if 'Applied' in Glassdoor.columns:
    Glassdoor=Glassdoor.drop(['Applied'],axis=1)
if 'Applied' in Indeed.columns:
    Indeed=Indeed.drop(['Applied'],axis=1)
if 'Applied' in Monster.columns:
    Monster=Monster.drop(['Applied'],axis=1)

# %%
Glassdoor[:5]
# Out:
#             KeyID       Date                      Company  \
# 0  gla-3068172040  1-24-2019  DiscoverOrg – Vancouver, WA
# 1  gla-3080883614  1-24-2019  DiscoverOrg – Vancouver, WA
# 2  gla-2983161073  1-24-2019  DiscoverOrg – Vancouver, WA
# 3  gla-3091635483   2-1-2019  DiscoverOrg – Vancouver, WA
# 4  gla-3071980823  1-10-2019  DiscoverOrg – Vancouver, WA
#
#                                             Position  \
# 0  4.4\r\nPrincipal Data Engineer\r\nDiscoverOrg ...
# 1  3.5\r\nAssociate Media Director\r\nAKQA Inc. –...
# 2  3.7\r\nBusiness Intelligence Data Analyst\r\nF...
# 3  3.6\r\nData Analyst\r\nNAVEX Global – Lake Osw...
# 4  4.4\r\nData Engineering Manager\r\nDiscoverOrg...
#
#                                                 Link  \
# 0  https://www.glassdoor.com/partner/jobListing.h...
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2  https://www.glassdoor.com/partner/jobListing.h...
# 3  https://www.glassdoor.com/partner/jobListing.h...
# ...

# %%
Indeed[:5]
# Out:
#                      KeyID       Date        Company  \
# 0  ind-pj_e2011b22e9168a37  1-31-2019           Azlo
# 1  ind-pj_549045552e32eb26  1-30-2019          Apple
# 2  ind-pj_a1daf14c9ca220ab  1-31-2019  Aspen Capital
# 3  ind-pj_d4e6a851cb5bd79a  1-29-2019  Aspen Capital
# 4  ind-pj_4f3d0af34b8e898f  1-29-2019  Aspen Capital
#
#                                             Position  \
# 0                                       Risk Analyst
# 1  ACG - Machine Learning R&D Engineer (Deep Lear...
# 2                                   Business Analyst
# 3                         Property Valuation Analyst
# 4                             Reconciliation Analyst
#
#                                                 Link  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...

# %%
Monster[:5]
# Out:
#                                       KeyID       Date            Company  \
# 0  mon-c12ab157-626e-4979-813d-313cc8ad66f2  1-29-2019     comScore, Inc.
# 1                             mon-204723940  1-22-2019       VanderHouwen
# 2                             mon-204915239  1-29-2019       Apex Systems
# 3  mon-08e9bf62-9a35-49a2-8193-e48b3d6fa20b   2-1-2019  Compri Consulting
# 4  mon-afb4d93b-2d17-4599-b328-ba78d93ed3e7  1-29-2019     comScore, Inc.
#
#                                             Position  \
# 0  Data Science Jobs in Portland, Oregon\r\n(148 ...
# 1                       Data Scientist, TV Analytics
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                     Data Science Platform Engineer
#
#                                                 Link  \
# 0  https://www.monster.com/jobs/search/?q=Data-Sc...
# 1  https://www.monster.com/jobs/search/?q=Data-Sc...
# ...

# %%
Glassdoor['Position']=str(Glassdoor['Position'])
Glassdoor['Position']=scrubadub(Glassdoor['Position'])
Glassdoor['Company']=scrubadub(Glassdoor['Company'])
Glassdoor['Description']=scrubadub(Glassdoor['Description'])
Indeed['Position']=scrubadub(Indeed['Position'])
Indeed['Company']=scrubadub(Indeed['Company'])
Indeed['Description']=scrubadub(Indeed['Description'])
Monster['Position']=scrubadub(Monster['Position'])
Monster['Company']=scrubadub(Monster['Company'])
Monster['Description']=scrubadub(Monster['Description'])

# %% [markdown]
# ______________

# %%
Larger_set_import=pd.read_csv('Total-scrape-2-1-2019.csv',sep='#')

# %%
if 'Applied' in Larger_set_import.columns:
    Larger_set_import=Larger_set_import.drop(['Applied'],axis=1)
if 'Unnamed: 0' in Larger_set_import.columns:
    Larger_set_import=Larger_set_import.drop(['Unnamed: 0'],axis=1)

# %%
Larger_set_import = Larger_set_import.append(Glassdoor,ignore_index=True,sort=False)
Larger_set_import = Larger_set_import.append(Indeed,ignore_index=True,sort=False)
Larger_set_import = Larger_set_import.append(Monster,ignore_index=True,sort=False)

# %%
Larger_set_import = Larger_set_import[['KeyID', 'Date', 'Company', 'Position','Description','Link']]

# %%
Larger_set_import
# Out:
#                                          KeyID        Date  \
# 0                               gla-3083564431    1-2-2019
# 1                               gla-2989422107   1-10-2019
# 2                               gla-2983161073  12-29-2018
# 3                               gla-3055085070  12-29-2018
# 4                               gla-2996000047    1-9-2019
# 5                               gla-3042963921  12-29-2018
# 6                               gla-2859138238  12-25-2018
# 7                               gla-3042963560  12-28-2018
# 8                               gla-3080911693   1-12-2019
# 9                               gla-3042964110    1-2-2019
# 10                              gla-3042963966   1-11-2019
# 11                              gla-3071980823    1-8-2019
# 12                              gla-3036050944    1-4-2019
# 13                              gla-3015320756    1-1-2019
# 14                              gla-2822860338   1-10-2019
# ...

# %%
from datetime import datetime 
d = datetime.today()
today=str(d.month)+'-'+str(d.day)+'-'+str(d.year)

#Larger_set_import.to_csv('Total-scrape-'+today+'.csv', sep=',')
#Larger_set_import.to_csv('Total-scrape.csv', sep=',')

# %%
Larger_set_import=pd.read_csv('Total-scrape.csv', sep=',')

# %%
if 'Unnamed: 0' in Larger_set_import.columns:
    Larger_set_import=Larger_set_import.drop(['Unnamed: 0'],axis=1) 
    
index_labels=list(Larger_set_import.columns)
index_labels=['key_id', 'job_dt', 'comp', 'job_pos', 'job_desc', 'job_link'] #modifying column names that PostGres would like
Larger_set_import.columns=index_labels

# %% [markdown]
# _________________________

# %% [markdown]
# To SQL Database
# =======

# %% [markdown]
# For this portion I setup pgAdmin 4.4 and used the interactive installer for postgres 11 (https://www.enterprisedb.com/downloads/postgres-postgresql-downloads) for Windows 10. I also installed SQLAlchemy and SQL Magic for Jupyter Notebooks.

# %%
import psycopg2
import sys
import pandas as pd
import sqlalchemy
import pyodbc
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:geezer@localhost/postgres
# Out:
# 'Connected: postgres@postgres'

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:geezer@localhost/postgres")

# write the DataFrame to a table in the sql database
Larger_set_import.to_sql("total_scrape", engine,if_exists='replace')

# %%
#%%sql
#DROP TABLE total_scrape

# %%
# %%sql
# select job_pos,job_desc
# from postgres.total_scrape
# where job_pos LIKE ('Data Scientist%')
# limit 5
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 5 rows affected.
# [('Data Scientist Simple Portland OR Glassdoor E days ago,', 'The Company We re a tech company thatchanging how people bank and think about their finances We value empathy curiosity craft and efficacy Our missio ... (5950 characters truncated) ... lication are true and complete to the best of your knowledge If you are employed false statements on your application will be grounds for termination'),
#  ('Data Scientist Indeed Prime Portland OR Hot,', 'Indeed Prime is a free service that connects qualified job seekers thatyou with top companies hiring tech roles With one application you can be consi ... (930 characters truncated) ... ady for a career changes and will be responsive to employers who reach out with job opportunities Get matched with top tech companies on Indeed Prime'),
# ...
